# %% [markdown]
# ###Task 1

# %%
#1. write a program to take a string as input and print its length

input = "veereswari"
print(len(input))
# Out:
# 10

# %%
#2. Given a string, convert it to uppercase and lowercase.

input = "veereswari"
print(input.upper())
print(input.lower())
# Out:
# VEERESWARI
# veereswari

# %%
#3. write a program to count the number of vowels in a string

s = "veereswari"
vowels = "aeiou"
count = 0

for ch in s:
    if ch in vowels:
       count += 1
print("number of vowels:",count)
# Out:
# number of vowels: 5

# %%
#4. check whether a given string is a panlindrome (example: madam).

s = "veera"
if s == s[::-1]:
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# not a palindrome

# %%
#5. Given a sentence, count the number of words in it.

sentence = "learning python is simple and python is powerful"
words = sentence.split()
print("number of words:",len(words))
# Out:
# number of words: 8

# %%
#6.Replace all space in a string with underscores(_).

input = "Learning python is simple and python is powerful"
result = input.replace(" ", "_")
print(result)
# Out:
# Learning_python_is_simple_and_python_is_powerful

# %%
#7. write a program to reverse a string without using built-in reverse functions.

str = "veereswari"
print(str[::-1])
# Out:
# irawsereev

# %% [markdown]
# #### Learning python is simple and python is powerful

# %%
#1. Given a string, remove leading and trailing spaces.

string = "   Learning python is simple and python is powerful   "
print(string.strip())
# Out:
# Learning python is simple and python is powerful

# %%
#2. Check whether a string start with a given character

check = string.startswith("   Learn")
check
# Out:
# True

# %%
#3. Find the index of the first occurance of the charecter in a strkng.

check_index = string.find("is")
print(check_index)
# Out:
# 19

# %%
#4. count how many times a specific character appears in a string.

string = "  Learing python is simple and python is powerful   "
count = string.count("is")
print("is appears for ",count,"times")
# Out:
# is appears for  2 times

# %%
#5. split a sentence into a list of words.

sentence = string.split()
sentence
# Out:
# ['Learing', 'python', 'is', 'simple', 'and', 'python', 'is', 'powerful']

# %%
#6. Join a list of words into a single string with spaces.

words = ['Learing', 'python', 'is', 'simple', 'and', 'python', 'is', 'powerful']
sentence =" ".join(words)
print(sentence)
# Out:
# Learing python is simple and python is powerful

# %%
#7.Replace a word in a sentencewith another word.

print(string)
replaced = string.replace(" ","_")
print(replaced)
# Out:
#   Learing python is simple and python is powerful
# __Learing_python_is_simple_and_python_is_powerful___
