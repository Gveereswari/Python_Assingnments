# %% [markdown]
# ### Assignment Questions

# %%
# Question 1: Create a set of first 10 natural numbers

for i in range(1,11):
    print(i,end="")
# Out:
# 12345678910

# %%
# Question 2: Add element 11 to set {1, 2, 3, 4, 5}

set1 = {1, 2, 3, 4, 5}
set1.add(11)
set1
# Out:
# {1, 2, 3, 4, 5, 11}

# %%
# Question 3: Remove element 3 from set {1, 2, 3, 4, 5, 6}

set1 = {1, 2, 3, 4, 5, 6}
set1.remove(3)
set1
# Out:
# {1, 2, 4, 5, 6}

# %%
# Question 4: Find the intersection of {1, 2, 3, 4, 5} and {4, 5, 6, 7, 8}
#way 1:

a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
c = a&b
print(c)

#way 2:
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
for i in a:
    if i in b:
        print(i,end="")
# Out:
# {4, 5}
# 45

# %%
# Question 5: Find the difference between {1, 2, 3, 4, 5} and {4, 5, 6, 7, 8}

a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
c = a.difference(b)
c
# Out:
# {1, 2, 3}

# %%
# Question 6: Check if 5 is in set {1, 2, 3, 4, 6, 7, 8}

set={1,2,3,4,5,6,7,8}
if 5 in set:
    print(" yes number is available in 5 variable name")
else:
    print("digit is not available in 5 variable ")
# Out:
#  yes number is available in 5 variable name

# %%
# Question 7: Find the length of set {'a', 'b', 'c', 'd', 'e'}

set={'a', 'b', 'c', 'd', 'e'}
length=len(set)
print(length)
# Out:
# 5

# %%
# Question 8: Create a set of vowels from string "hello world"

set="hello world"
vowel="aeiou"
for i in set.lower():
    if i in vowel:
        print(i ,end=" ")
# Out:
# e o o

# %%
# Question 9: Remove duplicates from list [1, 2, 2, 3, 4, 4, 5, 6, 6, 7] using set

lst = [1, 2, 2, 3, 4, 4, 5, 6, 6, 7]
unique_list = list(set(lst))
print(unique_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# Question 10: Check if {1, 2, 3} is a subset of {1, 2, 3, 4, 5, 6}

set1={1, 2, 3}
set2={1, 2, 3, 4, 5, 6}
print(set1.issubset(set2))
# Out:
# True
